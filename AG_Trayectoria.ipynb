# %% [markdown]
# <a href="https://colab.research.google.com/github/MateoMVP/Genetic-Algorithm/blob/main/AG_Trayectoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mateo Velasquez Penagos
#Si no encuentra una opcion optima de fitness 16 que es el esperado, aumetnar las iteraciones o correr varias veces el algoritmo hasta que lo encunetr
import random
random.seed(42) #Si quitamos el 42 de la funcion seed podemos ver inicializaciones aleatorias diferentes
characters = ['U', 'D', 'L', 'R']
cromosomaSize = 15
population_size = 100
generations = 1000
mutation_rate = 0.02

# %%
def generate_cromosoma(cromosomaSize):
  cromosoma = ''
  for i in range(cromosomaSize):
    cromosoma += random.choice(characters)
  return ''.join(cromosoma)

# %%
def fitness(cromosoma, posicion=(0, 0)):
    filas, columnas = posicion
    visited = set()
    visited.add((filas, columnas))
    moveAllowed = 0

    for move in cromosoma:
        if move == 'U' and filas > 0:
            filas -= 1

        elif move == 'D' and filas < 3:
            filas += 1

        elif move == 'L' and columnas > 0:
            columnas -= 1

        elif move == 'R' and columnas < 3:
            columnas += 1

        else:
            continue

        if (filas, columnas) not in visited:
            visited.add((filas, columnas))
            moveAllowed += 1  # Recompensar por visitar una nueva casilla
        else:
            moveAllowed += 0.5  # Penalizar por revisitar una casilla

    # Penalizar si no todas las casillas fueron visitadas
    noVisited = 16 - len(visited)
    fitness = moveAllowed + noVisited*10
    return fitness

# %%
#Seleccion metodo elitista
def selection(population):
  sorted_population = sorted(population, key=fitness, reverse=False)
  return sorted_population[0],sorted_population[1]

#Seleccion metodo por torneo
def tournament_selection(population,tournament_size):
  tournament = random.sample(population, tournament_size)
  best_in_tournament = min(tournament, key=fitness)
  best_in_tournament2 = min(tournament, key=fitness)
  return best_in_tournament, best_in_tournament2

# %%
#Cruce en un punto
def crossover(parent1, parent2):
  point = random.randint(1, len(parent1)) # Encunetra un punto aleatorio para cruzar los cromosomas en puntos aleatorios luego en el return los concatena
  return parent1[:point] + parent2[point:]

#Cruce en dos puntos
def crossover2(parent1, parent2):
  point1 = random.randint(1, len(parent1))
  point2 = random.randint(1, len(parent1))
  if point1 > point2:
    point1, point2 = point2, point1
  return parent1[:point1] + parent2[point1:point2] + parent1[point2:]

# %%
#Metodo de mutacion aleatoria
def mutation(cromosoma):
  cromosoma = list(cromosoma)
  for i in range(len(cromosoma)):
    if random.random() < mutation_rate:
      cromosoma[i] = random.choice(characters)
  return ''.join(cromosoma)

#Metodo de mutacion de inversion de genes
def inversionMutation(cromosoma):
  cromosoma = list(cromosoma)
  #print("Cromosoma original:", cromosoma)
  point1 = random.randint(1, len(cromosoma))
  cromosoma[point1:]=reversed(cromosoma[point1:])
  #print("Cromosoma después de la inversión:", cromosoma)
  return ''.join(cromosoma)

#print(inversionMutation(generate_cromosoma(cromosomaSize)))

# %%
def genetic_algoritm():
  #Genero poblacion con unas list compreheition
  population = [generate_cromosoma(cromosomaSize) for _ in range(population_size)]
  print(population)
  for generation in range(generations): # Recorro las generaciones
    padre1,padre2=selection(population)
    #padre1,padre2=tournament_selection(population,3)
    print(f"Generacion {generation}: {padre1} (Fitness: {fitness(padre1)}) ")
    if fitness(padre1) <= 16:
      print (f"Solucion encontrada en la generacion {generation}!")
      break
    next_generation = [padre1,padre2]
    while len(next_generation) < population_size:
      #cruce=crossover(padre1, padre2)
      cruce2=crossover2(padre1, padre2)
      #child = mutation(cruce)
      #child = inversionMutation(cruce)
      child = mutation(cruce2)
      #child = inversionMutation(cruce2)
      next_generation.append(child)
    population = next_generation

# %%
genetic_algoritm()
# Out:
# ['LURRRDRDULRDUDR', 'URRUUUUDRURLDUR', 'DRLDUDUDRULLDRL', 'ULUDDUURULRUURR', 'DUDUULLLRDLURLD', 'RLLRLLDDLRLDUUD', 'RRDURUUUULDLLLR', 'LLDDLUULLRRLDUD', 'RUUURLRUUDLRLLL', 'DDLDRDRDLLUUUUL', 'LLRRRURUUUDRURL', 'LDRLDRRLRLDLDDL', 'DDDLLUDDLDUULUU', 'ULUUDLDRRUDDRLD', 'DLLUURLULRDDDRU', 'RLRURDLLRLRRLLR', 'RLLURUDRLDLUULR', 'LRRLUUURLRUULUU', 'RDDDDUULDRUURDD', 'DLLULRULRLDRLDL', 'RLDRLUDLRLDDRUL', 'LLDLLURURDRULLR', 'UDUULRUDRULRRRD', 'LUDRRDDDRLRDLRL', 'DDDDURLULRLLUUL', 'DRURRULDLDRDUDD', 'RRDLRLRRRDLDDLD', 'DDURRLRLRRLURLD', 'RLDUURDLLDDDDUL', 'RDUDULLRRDULLUD', 'ULRLDUDDLDRLULU', 'LUDRDUURRRDLRLU', 'UULDDULUUUDLDLL', 'RULLRLRDRRDDDDL', 'LURRRRLDDLRRLUR', 'UULDDDDRULLLLRL', 'DDRLUULDDRDRRLD', 'LLDLURDDUDLUDRU', 'DLRUDLLURDDLLRD', 'LRRULRULLULDULD', 'LLULULLLRRRRUDR', 'DLLDLLRLULRDUDD', 'RRUDLLRLDUUULRR', 'DUDUDLRUDLDDDDR', 'RUDLUUDRDDRUDDD', 'RLLLRDLLDLLRRDU', 'DRDDRDDRLULDLUD', 'LUDURLRLRULLLDL', 'LURURURRRURLLUD', 'RURRLRULURUURRR', 'LDURLRDUUULDLDL', 'DLRLLRRRDDRLLDU', 'URRDDRUDRDDRDDR', 'RRRRLRRULRDURLU', 'URUUULDRDLUUDLR', 'DDLRLDUDRUUURLU', 'DUURRDLDRRRDLRL', 'DDULRLDLUDLLLRD', 'UDLDLDLLLUURRRR', 'DDLLDUDDULDUUUL', 'UUDRUDLRRRLULLU', 'ULUUDDDULDLURLL', 'RLLUUUUUULUURDR', 'DDDUURURUDRDUDU', 'LDUDURLUUUURDRR', 'RLLRRLRUUURUDUU', 'DDDDLUULUDLULDU', 'URLDRDDRLLLURDD', 'RDRDDULUDRLRLRU', 'RRULDLDURLDUULD', 'RLDUDURLRRLDLLD', 'RRLULLRDDULRLLL', 'RLRDLDUURDUDDUU', 'UDULDRRULLLUDDR', 'UDDDDLRDLRRDLDR', 'LDRUDULUDRDDLRR', 'RUDLDLRDRULULRR', 'RDLLLULLLLDUURD', 'LDDRRRURDLDRLRU', 'RDULURURUURDLUD', 'DUUURDULRLULRLL', 'RLRUDUURDRRLUDR', 'DRDDRDUURDUULRD', 'UUDRDRDURRRRLDU', 'ULRLDRRRRDURUDL', 'LUURLUDUUUULDDR', 'RDURRULLDULRURD', 'RRURULDDLLRURUR', 'ULDDRRLLLRURRDR', 'RRUULULUUDURULD', 'DRUDDULLDULDDDU', 'UDLDLDRLRULRLUD', 'LRRLLDRRURDLURL', 'UDULRULDDLRLLUL', 'LDDURRLDLLDLRRL', 'DURUDLRDRULRLRU', 'URUUUDDLRRDRRRR', 'DRLRRDLULDDUUUD', 'LLDDDRURDRRDDRL', 'UDDLLDUDLRDLRRD']
# Generacion 0: DRDDRDUURDUULRD (Fitness: 52.5)
# Generacion 1: DRURRDLDRRRDLRL (Fitness: 52.0)
# Generacion 2: DRURRDLDRDRDDRL (Fitness: 51)
# Generacion 3: DRURRDLDRDRDDLL (Fitness: 42)
# Generacion 4: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 5: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 6: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 7: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 8: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 9: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 10: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 11: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 12: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 13: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 14: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 15: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 16: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 17: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 18: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 19: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 20: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 21: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 22: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 23: DRURRDLDRDLDDLL (Fitness: 33)
# Generacion 24: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 25: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 26: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 27: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 28: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 29: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 30: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 31: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 32: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 33: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 34: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 35: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 36: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 37: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 38: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 39: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 40: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 41: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 42: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 43: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 44: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 45: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 46: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 47: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 48: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 49: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 50: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 51: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 52: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 53: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 54: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 55: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 56: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 57: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 58: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 59: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 60: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 61: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 62: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 63: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 64: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 65: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 66: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 67: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 68: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 69: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 70: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 71: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 72: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 73: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 74: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 75: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 76: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 77: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 78: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 79: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 80: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 81: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 82: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 83: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 84: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 85: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 86: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 87: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 88: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 89: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 90: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 91: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 92: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 93: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 94: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 95: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 96: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 97: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 98: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 99: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 100: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 101: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 102: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 103: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 104: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 105: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 106: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 107: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 108: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 109: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 110: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 111: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 112: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 113: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 114: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 115: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 116: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 117: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 118: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 119: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 120: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 121: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 122: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 123: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 124: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 125: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 126: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 127: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 128: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 129: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 130: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 131: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 132: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 133: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 134: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 135: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 136: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 137: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 138: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 139: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 140: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 141: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 142: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 143: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 144: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 145: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 146: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 147: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 148: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 149: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 150: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 151: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 152: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 153: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 154: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 155: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 156: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 157: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 158: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 159: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 160: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 161: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 162: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 163: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 164: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 165: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 166: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 167: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 168: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 169: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 170: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 171: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 172: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 173: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 174: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 175: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 176: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 177: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 178: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 179: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 180: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 181: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 182: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 183: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 184: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 185: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 186: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 187: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 188: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 189: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 190: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 191: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 192: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 193: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 194: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 195: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 196: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 197: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 198: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 199: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 200: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 201: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 202: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 203: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 204: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 205: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 206: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 207: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 208: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 209: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 210: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 211: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 212: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 213: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 214: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 215: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 216: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 217: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 218: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 219: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 220: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 221: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 222: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 223: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 224: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 225: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 226: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 227: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 228: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 229: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 230: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 231: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 232: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 233: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 234: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 235: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 236: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 237: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 238: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 239: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 240: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 241: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 242: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 243: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 244: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 245: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 246: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 247: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 248: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 249: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 250: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 251: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 252: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 253: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 254: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 255: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 256: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 257: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 258: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 259: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 260: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 261: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 262: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 263: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 264: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 265: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 266: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 267: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 268: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 269: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 270: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 271: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 272: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 273: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 274: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 275: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 276: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 277: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 278: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 279: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 280: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 281: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 282: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 283: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 284: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 285: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 286: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 287: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 288: DRURRDLDRDLDLUL (Fitness: 24)
# Generacion 289: DRURRDLDRDLLLUR (Fitness: 15)
# Solucion encontrada en la generacion 289!

# %%
#Funcion para mostrar la matriz recorrida por el cromosoma resultado, se le debe asignar el cromosoma resultante de manera manual

def print_path(cromosoma, start_position=(0, 0)):
    filas, columnas = start_position
    grid = [['.' for _ in range(4)] for _ in range(4)]
    grid[filas][columnas] = 'Start'  # Indica la posición inicial

    for move in cromosoma:
        if move == 'U' and filas > 0:
            filas -= 1
            grid[filas][columnas] = 'arriba'
        elif move == 'D' and filas < 3:
            filas += 1
            grid[filas][columnas] = 'abajo'
        elif move == 'L' and columnas > 0:
            columnas -= 1
            grid[filas][columnas] = 'izquierda'
        elif move == 'R' and columnas < 3:
            columnas += 1
            grid[filas][columnas] = 'derecha'

    return grid

cromosoma = 'DRURRDLDRDLLLUR'
print_path(cromosoma)
# Out:
# [['Start', 'arriba', 'derecha', 'derecha'],
#  ['abajo', 'derecha', 'izquierda', 'abajo'],
#  ['arriba', 'derecha', 'abajo', 'derecha'],
#  ['izquierda', 'izquierda', 'izquierda', 'abajo']]
